# %%
#ditionary operations
person= {'name':'priya','age':'20','city':'nuzvid'}
print(person)
print("accesing and modifying the person age:")
person["age"]= 31
print(person)
print("Adding and removing items")
person['email']= 'lalithapriyankanadikoppu@gmail.com'
print(person)
del person['city']
print(person)
print("All keys & values")
print(person.keys())
print(person.values())
