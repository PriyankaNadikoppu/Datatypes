# %%
# set operations
my_set={1,2,3,4,5,6}
print(my_set)
print("add and remove value")
my_set.add(7)
print(my_set)
my_set.remove(2)
my_set.discard(5)
print(my_set)
print("membership check")
print(1 in my_set)
print(10 in my_set)
